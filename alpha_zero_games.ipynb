# %%
import pandas as pd

# %%
df = pd.read_csv("alpha0_fixed.csv",index_col=False, header=None)

# %%
df
# Out:
#                             0              1                    2  \
# 0    [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 1    [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 2    [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 3    [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 4    [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 5    [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 6    [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 7    [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 8    [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 9    [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 10   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 11   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 12   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 13   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 14   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 15   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 16   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 17   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 18   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 19   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 20   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 21   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 22   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 23   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 24   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 25   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 26   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 27   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 28   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 29   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# ..                        ...            ...                  ...
# 81   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 82   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 83   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 84   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 85   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 86   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 87   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 88   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 89   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 90   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 91   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 92   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 93   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 94   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 95   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 96   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 97   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 98   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 99   [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 100  [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 101  [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 102  [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 103  [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 104  [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 105  [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 106  [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 107  [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 108  [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 109  [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
# 110  [Event "Computer Match"]  [Site "London  [Date "2018.01.18"]
#
#                                   3                      4  \
# 0    [Round "11542767294934054345"]    [White "AlphaZero"]
# 1     [Round "9631440984287896022"]    [White "AlphaZero"]
# 2     [Round "9590777183283011846"]    [White "AlphaZero"]
# 3     [Round "8542537617948137496"]    [White "AlphaZero"]
# 4     [Round "7647098068760231528"]    [White "AlphaZero"]
# 5     [Round "7140698033500703341"]    [White "AlphaZero"]
# 6      [Round "691859931675082058"]    [White "AlphaZero"]
# 7     [Round "6789699321684269484"]    [White "AlphaZero"]
# 8      [Round "669650148418876874"]    [White "AlphaZero"]
# 9     [Round "6694459919267050122"]    [White "AlphaZero"]
# 10    [Round "6640061131152476226"]    [White "AlphaZero"]
# 11    [Round "5975790206778120659"]    [White "AlphaZero"]
# 12    [Round "4675640728464940612"]    [White "AlphaZero"]
# 13    [Round "4548207250304038355"]    [White "AlphaZero"]
# 14    [Round "4229355007191865808"]    [White "AlphaZero"]
# 15    [Round "3792448887452614000"]    [White "AlphaZero"]
# 16    [Round "1869259036589376380"]    [White "AlphaZero"]
# 17   [Round "18324114048812201021"]    [White "AlphaZero"]
# 18   [Round "18142250296643798060"]    [White "AlphaZero"]
# 19   [Round "18085936221980441161"]    [White "AlphaZero"]
# 20   [Round "17950604089883009910"]    [White "AlphaZero"]
# 21    [Round "1781245371808176215"]    [White "AlphaZero"]
# 22   [Round "17760757200045262106"]    [White "AlphaZero"]
# 23   [Round "17454695395454774250"]    [White "AlphaZero"]
# 24   [Round "16923207931856362105"]    [White "AlphaZero"]
# 25   [Round "16674612722588330663"]    [White "AlphaZero"]
# 26   [Round "16513206743872013240"]    [White "AlphaZero"]
# 27   [Round "15757864129744024444"]    [White "AlphaZero"]
# 28     [Round "156228366932102227"]    [White "AlphaZero"]
# 29   [Round "15379219795039538574"]    [White "AlphaZero"]
# ..                              ...                    ...
# 81    [Round "7648741535486894284"]    [White "AlphaZero"]
# 82    [Round "7078804245524558596"]    [White "AlphaZero"]
# 83    [Round "5401044856701022972"]    [White "AlphaZero"]
# 84    [Round "5224369490612317085"]    [White "AlphaZero"]
# 85    [Round "4632333797861372679"]    [White "AlphaZero"]
# 86    [Round "4500334006973447547"]    [White "AlphaZero"]
# 87    [Round "3677026750049642053"]    [White "AlphaZero"]
# 88    [Round "3283815011293825606"]    [White "AlphaZero"]
# 89   [Round "18032836818162942537"]    [White "AlphaZero"]
# 90   [Round "17783665650825009718"]    [White "AlphaZero"]
# 91   [Round "16601626363786679617"]    [White "AlphaZero"]
# 92   [Round "16001156000889552113"]    [White "AlphaZero"]
# 93    [Round "1353243518697010232"]    [White "AlphaZero"]
# 94   [Round "13376850553810558906"]    [White "AlphaZero"]
# 95   [Round "13376850553810558906"]    [White "AlphaZero"]
# 96   [Round "13242102066133112446"]    [White "AlphaZero"]
# 97   [Round "13228955388346083299"]    [White "AlphaZero"]
# 98   [Round "10171852109272918171"]    [White "AlphaZero"]
# 99     [Round "982143359799313906"]  [White "Stockfish 8"]
# 100  [Round "17293012532641473451"]  [White "Stockfish 8"]
# 101   [Round "1311451608356943530"]  [White "Stockfish 8"]
# 102  [Round "14385736216385115953"]  [White "Stockfish 8"]
# 103  [Round "17896041660018278286"]  [White "Stockfish 8"]
# 104   [Round "5361299757472136882"]  [White "Stockfish 8"]
# 105   [Round "3353787938484647500"]    [White "AlphaZero"]
# 106   [Round "5236993464467552754"]    [White "AlphaZero"]
# 107  [Round "17494942703158718757"]    [White "AlphaZero"]
# 108   [Round "5392718751057140516"]    [White "AlphaZero"]
# 109  [Round "11882219725075081943"]    [White "AlphaZero"]
# 110   [Round "6854337384941683259"]    [White "AlphaZero"]
#
#                          5                   6  \
# 0    [Black "Stockfish 8"]      [Result "1-0"]
# 1    [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 2    [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 3    [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 4    [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 5    [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 6    [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 7    [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 8    [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 9    [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 10   [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 11   [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 12   [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 13   [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 14   [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 15   [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 16   [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 17   [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 18   [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 19   [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 20   [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 21   [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 22   [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 23   [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 24   [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 25   [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 26   [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 27   [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 28   [Black "Stockfish 8"]  [Result "1/2-1/2"]
# 29   [Black "Stockfish 8"]  [Result "1/2-1/2"]
# ..                     ...                 ...
# 81   [Black "Stockfish 8"]      [Result "1-0"]
# 82   [Black "Stockfish 8"]      [Result "1-0"]
# 83   [Black "Stockfish 8"]      [Result "1-0"]
# 84   [Black "Stockfish 8"]      [Result "1-0"]
# 85   [Black "Stockfish 8"]      [Result "1-0"]
# 86   [Black "Stockfish 8"]      [Result "1-0"]
# 87   [Black "Stockfish 8"]      [Result "1-0"]
# 88   [Black "Stockfish 8"]      [Result "1-0"]
# 89   [Black "Stockfish 8"]      [Result "1-0"]
# 90   [Black "Stockfish 8"]      [Result "1-0"]
# 91   [Black "Stockfish 8"]      [Result "1-0"]
# 92   [Black "Stockfish 8"]      [Result "1-0"]
# 93   [Black "Stockfish 8"]      [Result "1-0"]
# 94   [Black "Stockfish 8"]      [Result "1-0"]
# 95   [Black "Stockfish 8"]      [Result "1-0"]
# 96   [Black "Stockfish 8"]      [Result "1-0"]
# 97   [Black "Stockfish 8"]      [Result "1-0"]
# 98   [Black "Stockfish 8"]      [Result "1-0"]
# 99     [Black "AlphaZero"]      [Result "0-1"]
# 100    [Black "AlphaZero"]      [Result "0-1"]
# 101    [Black "AlphaZero"]      [Result "0-1"]
# 102    [Black "AlphaZero"]      [Result "1-0"]
# 103    [Black "AlphaZero"]      [Result "0-1"]
# 104    [Black "AlphaZero"]      [Result "0-1"]
# 105  [Black "Stockfish 8"]      [Result "1-0"]
# 106  [Black "Stockfish 8"]      [Result "1-0"]
# 107  [Black "Stockfish 8"]      [Result "1-0"]
# 108  [Black "Stockfish 8"]      [Result "1-0"]
# 109  [Black "Stockfish 8"]      [Result "1-0"]
# 110  [Black "Stockfish 8"]      [Result "1-0"]
#
#                                                      7
# 0    1. Nf3 Nf6 2. c4 e6\n3. Nc3 Bb4 4. Qc2 O-O\n5....
# 1    1. d4 Nf6 2. Nf3 e6\n3. c4 b6 4. g3 Bb4+\n5. B...
# 2    1. Nf3 Nf6 2. c4 e6\n3. Nc3 Bb4 4. Qc2 O-O\n5....
# 3    1. d4 Nf6 2. c4 e6\n3. Nc3 Bb4 4. Nf3 b6\n5. Q...
# 4    1. d4 Nf6 2. Nf3 e6\n3. c4 d5 4. Nc3 c6\n5. Bg...
# 5    1. d4 Nf6 2. c4 e6\n3. Nc3 Bb4 4. e3 O-O\n5. B...
# 6    1. Nf3 e6 2. c4 Nf6\n3. Nc3 Bb4 4. Qc2 O-O\n5....
# 7    1. d4 Nf6 2. Nf3 e6\n3. c4 b6 4. g3 Bb4+\n5. B...
# 8    1. Nf3 Nf6 2. d4 d5\n3. c4 e6 4. g3 Bb4+\n5. B...
# 9    1. Nf3 Nf6 2. c4 e6\n3. d4 b6 4. g3 Bb4+\n5. B...
# 10   1. d4 Nf6 2. Nf3 e6\n3. c4 b6 4. g3 Ba6\n5. Nb...
# 11   1. d4 Nf6 2. c4 e6\n3. g3 d5 4. Nf3 Bb4+\n5. B...
# 12   1. d4 Nf6 2. Nf3 d5\n3. Bf4 c5 4. e3 Nc6\n5. N...
# 13   1. Nf3 e6 2. c4 Nf6\n3. Nc3 Bb4 4. Qc2 O-O\n5....
# 14   1. Nf3 e6 2. e4 d5\n3. e5 c5 4. c3 Nc6\n5. d4 ...
# 15   1. d4 Nf6 2. c4 e6\n3. Nf3 b6 4. g3 Bb7\n5. Bg...
# 16   1. d4 Nf6 2. Nf3 e6\n3. c4 h6 4. Nc3 Bb4\n5. Q...
# 17   1. d4 Nf6 2. c4 e6\n3. Nf3 b6 4. g3 Ba6\n5. b3...
# 18   1. d4 Nf6 2. Nf3 e6\n3. c4 b6 4. g3 Ba6\n5. Nb...
# 19   1. Nf3 e6 2. c4 Nf6\n3. Nc3 Bb4 4. Qc2 O-O\n5....
# 20   1. d4 Nf6 2. c4 e6\n3. Nc3 Bb4 4. Nf3 b6\n5. e...
# 21   1. d4 Nf6 2. c4 e6\n3. g3 Bb4+ 4. Bd2 Be7\n5. ...
# 22   1. d4 Nf6 2. c4 e6\n3. Nc3 Bb4 4. e3 O-O\n5. N...
# 23   1. d4 Nf6 2. c4 e6\n3. Nc3 Bb4 4. e3 O-O\n5. B...
# 24   1. d4 e6 2. e4 d5\n3. Nc3 Nf6 4. e5 Nfd7\n5. f...
# 25   1. d4 Nf6 2. Nf3 e6\n3. c4 b6 4. g3 Be7\n5. Bg...
# 26   1. d4 Nf6 2. Nf3 e6\n3. c4 d5 4. Nc3 c6\n5. Bg...
# 27   1. d4 e6 2. e4 d5\n3. Nc3 Nf6 4. e5 Nfd7\n5. f...
# 28   1. d4 Nf6 2. c4 e6\n3. Nf3 b6 4. g3 Bb7\n5. Bg...
# 29   1. d4 Nf6 2. Nf3 b6\n3. c4 Bb7 4. g3 e6\n5. Bg...
# ..                                                 ...
# 81   1. d4 Nf6 2. c4 e6\n3. g3 Bb4+ 4. Bd2 Be7\n5. ...
# 82   1. Nf3 Nf6 2. c4 e6\n3. Nc3 Bb4 4. Qc2 O-O\n5....
# 83   1. Nf3 Nf6 2. c4 c5\n3. Nc3 Nc6 4. g3 e5\n5. B...
# 84   1. d4 Nf6 2. c4 e6\n3. Nc3 d5 4. cxd5 exd5\n5....
# 85   1. Nf3 Nf6 2. d4 b6\n3. g3 e6 4. Bg2 Bb7\n5. c...
# 86   1. d4 Nf6 2. c4 e6\n3. Nc3 Bb4 4. e3 O-O\n5. B...
# 87   1. d4 Nf6 2. Nf3 e6\n3. c4 b6 4. g3 Ba6\n5. Qc...
# 88   1. d4 Nf6 2. Nf3 e6\n3. c4 b6 4. g3 Be7\n5. Nc...
# 89   1. Nf3 e6 2. c4 Nf6\n3. Nc3 Bb4 4. Qc2 O-O\n5....
# 90   1. d4 Nf6 2. Nf3 e6\n3. c4 b6 4. g3 Bb4+\n5. B...
# 91   1. Nf3 Nf6 2. d4 e6\n3. c4 d5 4. Nc3 c6\n5. Bg...
# 92   1. d4 Nf6 2. c4 e6\n3. g3 Bb4+ 4. Bd2 Be7\n5. ...
# 93   1. Nf3 e6 2. c4 Nf6\n3. Nc3 Bb4 4. Qc2 O-O\n5....
# 94   1. d4 Nf6 2. Nf3 e6\n3. c4 b6 4. g3 Ba6\n5. b3...
# 95   1. d4 Nf6 2. Nf3 e6\n3. c4 b6 4. g3 Ba6\n5. b3...
# 96   1. d4 Nf6 2. c4 e6\n3. Nf3 b6 4. g3 Bb7\n5. Bg...
# 97   1. Nf3 Nf6 2. d4 d5\n3. c4 e6 4. Nc3 c6\n5. Bg...
# 98   1. d4 Nf6 2. Nf3 b61. d4 Nf6 2. Nf3 b6\n3. c4 ...
# 99   1. e4 e5 2. Nf3 Nc6\n3. Bb5 Nf6 4. O-O Nxe4\n5...
# 100  1. e4 e5 2. Nf3 Nc6\n3. Bc4 Nf6 4. Ng5 d5\n5. ...
# 101  1. e4 e5 2. Nf3 Nc6\n3. Bb5 Nf6 4. O-O Nxe4\n5...
# 102  1. e4 e5 2. Nf3 Nc63. Bb5 Nf6 4. O-O Nxe4\n5. ...
# 103  1. e4 e5 2. Nf3 Nc6\n3. Bc4 Bc5 4. d3 a6\n5. N...
# 104  1. e4 e5 2. Nf3 Nc6\n3. Bb5 Nf6 4. O-O Nxe4\n5...
# 105  1. Nf3 Nf6 2. c4 c5\n3. Nc3 e6 4. g3 Qb6\n5. d...
# 106  1. Nf3 Nf6 2. c4 c5\n3. Nc3 e6 4. g3 Qb6\n5. d...
# 107  1. d4 Nf6 2. Nf3 e6\n3. c4 b6 4. g3 Bb7\n5. Bg...
# 108  1. Nf3 e6 2. c4 Nf6\n3. Nc3 Bb4 4. Qc2 O-O\n5....
# 109  1. d4 Nf6 2. c4 e6\n3. Nf3 b6 4. g3 Bb7\n5. Bg...
# 110  1. d4 Nf6 2. c4 e6\n3. Nf3 b6 4. g3 Bb7\n5. Bg...
#
# [111 rows x 8 columns]

# %%
df[7]=df[7].apply(lambda x : x.replace("\n",""))

# %%
df = df.drop([0,1,2,3], axis=1)

# %%
df = df.rename(index=str, columns={4: 'white', 5:'black',6:'winner',7:'moves'})

# %%
df['white']=df['white'].apply(lambda x: str.split(x)[1])
df['black']=df['black'].apply(lambda x: str.split(x)[1])

# %%
df = df.replace('"AlphaZero"]',"AlphaZero")
df = df.replace('"Stockfish',"Stockfish8")
df = df.replace('[Result "1/2-1/2"]',0.5)
df = df.replace('[Result "1-0"]',1.0)
df = df.replace('[Result "0-1"]',0.0)

# %%
df
# Out:
#           white       black winner  \
# 0     AlphaZero  Stockfish8      1
# 1     AlphaZero  Stockfish8    0.5
# 2     AlphaZero  Stockfish8    0.5
# 3     AlphaZero  Stockfish8    0.5
# 4     AlphaZero  Stockfish8    0.5
# 5     AlphaZero  Stockfish8    0.5
# 6     AlphaZero  Stockfish8    0.5
# 7     AlphaZero  Stockfish8    0.5
# 8     AlphaZero  Stockfish8    0.5
# 9     AlphaZero  Stockfish8    0.5
# 10    AlphaZero  Stockfish8    0.5
# 11    AlphaZero  Stockfish8    0.5
# 12    AlphaZero  Stockfish8    0.5
# 13    AlphaZero  Stockfish8    0.5
# 14    AlphaZero  Stockfish8    0.5
# 15    AlphaZero  Stockfish8    0.5
# 16    AlphaZero  Stockfish8    0.5
# 17    AlphaZero  Stockfish8    0.5
# 18    AlphaZero  Stockfish8    0.5
# 19    AlphaZero  Stockfish8    0.5
# 20    AlphaZero  Stockfish8    0.5
# 21    AlphaZero  Stockfish8    0.5
# 22    AlphaZero  Stockfish8    0.5
# 23    AlphaZero  Stockfish8    0.5
# 24    AlphaZero  Stockfish8    0.5
# 25    AlphaZero  Stockfish8    0.5
# 26    AlphaZero  Stockfish8    0.5
# 27    AlphaZero  Stockfish8    0.5
# 28    AlphaZero  Stockfish8    0.5
# 29    AlphaZero  Stockfish8    0.5
# ..          ...         ...    ...
# 81    AlphaZero  Stockfish8      1
# 82    AlphaZero  Stockfish8      1
# 83    AlphaZero  Stockfish8      1
# 84    AlphaZero  Stockfish8      1
# 85    AlphaZero  Stockfish8      1
# 86    AlphaZero  Stockfish8      1
# 87    AlphaZero  Stockfish8      1
# 88    AlphaZero  Stockfish8      1
# 89    AlphaZero  Stockfish8      1
# 90    AlphaZero  Stockfish8      1
# 91    AlphaZero  Stockfish8      1
# 92    AlphaZero  Stockfish8      1
# 93    AlphaZero  Stockfish8      1
# 94    AlphaZero  Stockfish8      1
# 95    AlphaZero  Stockfish8      1
# 96    AlphaZero  Stockfish8      1
# 97    AlphaZero  Stockfish8      1
# 98    AlphaZero  Stockfish8      1
# 99   Stockfish8   AlphaZero      0
# 100  Stockfish8   AlphaZero      0
# 101  Stockfish8   AlphaZero      0
# 102  Stockfish8   AlphaZero      1
# 103  Stockfish8   AlphaZero      0
# 104  Stockfish8   AlphaZero      0
# 105   AlphaZero  Stockfish8      1
# 106   AlphaZero  Stockfish8      1
# 107   AlphaZero  Stockfish8      1
# 108   AlphaZero  Stockfish8      1
# 109   AlphaZero  Stockfish8      1
# 110   AlphaZero  Stockfish8      1
#
#                                                  moves
# 0    1. Nf3 Nf6 2. c4 e63. Nc3 Bb4 4. Qc2 O-O5. a3 ...
# 1    1. d4 Nf6 2. Nf3 e63. c4 b6 4. g3 Bb4+5. Bd2 B...
# 2    1. Nf3 Nf6 2. c4 e63. Nc3 Bb4 4. Qc2 O-O5. a3 ...
# 3    1. d4 Nf6 2. c4 e63. Nc3 Bb4 4. Nf3 b65. Qc2 B...
# 4    1. d4 Nf6 2. Nf3 e63. c4 d5 4. Nc3 c65. Bg5 Nb...
# 5    1. d4 Nf6 2. c4 e63. Nc3 Bb4 4. e3 O-O5. Bd2 b...
# 6    1. Nf3 e6 2. c4 Nf63. Nc3 Bb4 4. Qc2 O-O5. a3 ...
# 7    1. d4 Nf6 2. Nf3 e63. c4 b6 4. g3 Bb4+5. Bd2 B...
# 8    1. Nf3 Nf6 2. d4 d53. c4 e6 4. g3 Bb4+5. Bd2 B...
# 9    1. Nf3 Nf6 2. c4 e63. d4 b6 4. g3 Bb4+5. Bd2 B...
# 10   1. d4 Nf6 2. Nf3 e63. c4 b6 4. g3 Ba65. Nbd2 B...
# 11   1. d4 Nf6 2. c4 e63. g3 d5 4. Nf3 Bb4+5. Bd2 B...
# 12   1. d4 Nf6 2. Nf3 d53. Bf4 c5 4. e3 Nc65. Nbd2 ...
# 13   1. Nf3 e6 2. c4 Nf63. Nc3 Bb4 4. Qc2 O-O5. a3 ...
# 14   1. Nf3 e6 2. e4 d53. e5 c5 4. c3 Nc65. d4 Qb6 ...
# 15   1. d4 Nf6 2. c4 e63. Nf3 b6 4. g3 Bb75. Bg2 Be...
# 16   1. d4 Nf6 2. Nf3 e63. c4 h6 4. Nc3 Bb45. Qc2 d...
# 17   1. d4 Nf6 2. c4 e63. Nf3 b6 4. g3 Ba65. b3 Bb4...
# 18   1. d4 Nf6 2. Nf3 e63. c4 b6 4. g3 Ba65. Nbd2 d...
# 19   1. Nf3 e6 2. c4 Nf63. Nc3 Bb4 4. Qc2 O-O5. a3 ...
# 20   1. d4 Nf6 2. c4 e63. Nc3 Bb4 4. Nf3 b65. e3 Bb...
# 21   1. d4 Nf6 2. c4 e63. g3 Bb4+ 4. Bd2 Be75. Bg2 ...
# 22   1. d4 Nf6 2. c4 e63. Nc3 Bb4 4. e3 O-O5. Nf3 d...
# 23   1. d4 Nf6 2. c4 e63. Nc3 Bb4 4. e3 O-O5. Bd3 d...
# 24   1. d4 e6 2. e4 d53. Nc3 Nf6 4. e5 Nfd75. f4 c5...
# 25   1. d4 Nf6 2. Nf3 e63. c4 b6 4. g3 Be75. Bg2 Bb...
# 26   1. d4 Nf6 2. Nf3 e63. c4 d5 4. Nc3 c65. Bg5 Be...
# 27   1. d4 e6 2. e4 d53. Nc3 Nf6 4. e5 Nfd75. f4 c5...
# 28   1. d4 Nf6 2. c4 e63. Nf3 b6 4. g3 Bb75. Bg2 Be...
# 29   1. d4 Nf6 2. Nf3 b63. c4 Bb7 4. g3 e65. Bg2 Be...
# ..                                                 ...
# 81   1. d4 Nf6 2. c4 e63. g3 Bb4+ 4. Bd2 Be75. Bg2 ...
# 82   1. Nf3 Nf6 2. c4 e63. Nc3 Bb4 4. Qc2 O-O5. a3 ...
# 83   1. Nf3 Nf6 2. c4 c53. Nc3 Nc6 4. g3 e55. Bg2 B...
# 84   1. d4 Nf6 2. c4 e63. Nc3 d5 4. cxd5 exd55. Bg5...
# 85   1. Nf3 Nf6 2. d4 b63. g3 e6 4. Bg2 Bb75. c4 Bb...
# 86   1. d4 Nf6 2. c4 e63. Nc3 Bb4 4. e3 O-O5. Bd3 c...
# 87   1. d4 Nf6 2. Nf3 e63. c4 b6 4. g3 Ba65. Qc2 c5...
# 88   1. d4 Nf6 2. Nf3 e63. c4 b6 4. g3 Be75. Nc3 Bb...
# 89   1. Nf3 e6 2. c4 Nf63. Nc3 Bb4 4. Qc2 O-O5. a3 ...
# 90   1. d4 Nf6 2. Nf3 e63. c4 b6 4. g3 Bb4+5. Bd2 B...
# 91   1. Nf3 Nf6 2. d4 e63. c4 d5 4. Nc3 c65. Bg5 Be...
# 92   1. d4 Nf6 2. c4 e63. g3 Bb4+ 4. Bd2 Be75. Bg2 ...
# 93   1. Nf3 e6 2. c4 Nf63. Nc3 Bb4 4. Qc2 O-O5. a3 ...
# 94   1. d4 Nf6 2. Nf3 e63. c4 b6 4. g3 Ba65. b3 Bb4...
# 95   1. d4 Nf6 2. Nf3 e63. c4 b6 4. g3 Ba65. b3 Bb4...
# 96   1. d4 Nf6 2. c4 e63. Nf3 b6 4. g3 Bb75. Bg2 Be...
# 97   1. Nf3 Nf6 2. d4 d53. c4 e6 4. Nc3 c65. Bg5 h6...
# 98   1. d4 Nf6 2. Nf3 b61. d4 Nf6 2. Nf3 b63. c4 e6...
# 99   1. e4 e5 2. Nf3 Nc63. Bb5 Nf6 4. O-O Nxe45. Re...
# 100  1. e4 e5 2. Nf3 Nc63. Bc4 Nf6 4. Ng5 d55. exd5...
# 101  1. e4 e5 2. Nf3 Nc63. Bb5 Nf6 4. O-O Nxe45. d4...
# 102  1. e4 e5 2. Nf3 Nc63. Bb5 Nf6 4. O-O Nxe45. d4...
# 103  1. e4 e5 2. Nf3 Nc63. Bc4 Bc5 4. d3 a65. Ng5 N...
# 104  1. e4 e5 2. Nf3 Nc63. Bb5 Nf6 4. O-O Nxe45. d4...
# 105  1. Nf3 Nf6 2. c4 c53. Nc3 e6 4. g3 Qb65. d3 d5...
# 106  1. Nf3 Nf6 2. c4 c53. Nc3 e6 4. g3 Qb65. d3 d5...
# 107  1. d4 Nf6 2. Nf3 e63. c4 b6 4. g3 Bb75. Bg2 Bb...
# 108  1. Nf3 e6 2. c4 Nf63. Nc3 Bb4 4. Qc2 O-O5. a3 ...
# 109  1. d4 Nf6 2. c4 e63. Nf3 b6 4. g3 Bb75. Bg2 Be...
# 110  1. d4 Nf6 2. c4 e63. Nf3 b6 4. g3 Bb75. Bg2 Bb...
#
# [111 rows x 4 columns]
